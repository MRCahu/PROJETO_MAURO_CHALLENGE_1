# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
# prompt: Nesta primeira análise, você deve calcular o faturamento total de cada loja. Somando os valores da coluna Preço de cada loja para estimar o faturamento.

faturamento_loja1 = loja['Preço'].sum()
faturamento_loja2 = loja2['Preço'].sum()
faturamento_loja3 = loja3['Preço'].sum()
faturamento_loja4 = loja4['Preço'].sum()

print(f"Faturamento Loja 1: R${faturamento_loja1:,.2f}")
print(f"Faturamento Loja 2: R${faturamento_loja2:,.2f}")
print(f"Faturamento Loja 3: R${faturamento_loja3:,.2f}")
print(f"Faturamento Loja 4: R${faturamento_loja4:,.2f}")
# Out:
# Faturamento Loja 1: R$1,534,509.12
# Faturamento Loja 2: R$1,488,459.06
# Faturamento Loja 3: R$1,464,025.03
# Faturamento Loja 4: R$1,384,497.58

# %%
# import matplotlib.pyplot as plt
# # Calcular o faturamento total (Preço + Frete) e total de vendas (linhas) por loja
# faturamento = {}
# volume_vendas = {}
# for nome, df in lojas.items():
#     df['Faturamento'] = df['Preço'] + df['Frete']
#     faturamento[nome] = df['Faturamento'].sum()
#     volume_vendas[nome] = len(df)
# # Preparar gráfico
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.bar(faturamento.keys(), faturamento.values(), color='skyblue')
# ax.set_title('Faturamento Total por Loja')
# ax.set_ylabel('R$')
# ax.set_xlabel('Loja')
# plt.xticks(rotation=45)
# plt.grid(axis='y')
# plt.tight_layout()
# plt.show()
# # Retornar os valores numéricos também
# faturamento, volume_vendas

import pandas as pd
import matplotlib.pyplot as plt

# URLs dos arquivos CSV
urls = {
    "loja_1": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv",
    "loja_2": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv",
    "loja_3": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv",
    "loja_4": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"
}

# Carregar os DataFrames
lojas = {}
for nome, url in urls.items():
    lojas[nome] = pd.read_csv(url)

# Calcular o faturamento total (Preço + Frete) e total de vendas (linhas) por loja
faturamento = {}
volume_vendas = {}
for nome, df in lojas.items():
    df['Faturamento'] = df['Preço'] + df['Frete']
    faturamento[nome] = df['Faturamento'].sum()
    volume_vendas[nome] = len(df)

# Preparar gráfico
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(faturamento.keys(), faturamento.values(), color='skyblue')
ax.set_title('Faturamento Total por Loja')
ax.set_ylabel('R$')
ax.set_xlabel('Loja')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# Exibir o faturamento e o volume de vendas
print("Faturamento por Loja:")
for loja, valor in faturamento.items():
    print(f"{loja}: R${valor:,.2f}")

print("\nVolume de Vendas por Loja:")
for loja, valor in volume_vendas.items():
    print(f"{loja}: {valor}")
# Out:
# Faturamento por Loja:
# loja_1: R$1,616,347.09
# loja_2: R$1,567,773.22
# loja_3: R$1,542,047.69
# loja_4: R$1,458,253.46
#
# Volume de Vendas por Loja:
# loja_1: 2359
# loja_2: 2359
# loja_3: 2359
# loja_4: 2358

# %%
# # Recalcular faturamento apenas com base na coluna 'Preço'
# faturamento_simples = {nome: df['Preço'].sum() for nome, df in lojas.items()}
# # Gerar gráfico atualizado com base no novo critério
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.bar(faturamento_simples.keys(), faturamento_simples.values(), color='mediumseagreen')
# ax.set_title('Faturamento Total (Somente Preço) por Loja')
# ax.set_ylabel('R$')
# ax.set_xlabel('Loja')
# plt.xticks(rotation=45)
# plt.grid(axis='y')
# plt.tight_layout()
# plt.show()
# faturamento_simples

import pandas as pd
import matplotlib.pyplot as plt

# URLs dos arquivos CSV
urls = {
    "loja_1": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv",
    "loja_2": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv",
    "loja_3": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv",
    "loja_4": "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"
}

# Carregar os DataFrames
lojas = {}
for nome, url in urls.items():
    lojas[nome] = pd.read_csv(url)

# Recalcular faturamento apenas com base na coluna 'Preço' para todas as lojas
faturamento_simples = {}
for nome, df in lojas.items():
  faturamento_simples[nome] = df['Preço'].sum()

# Gerar gráfico atualizado com base no novo critério
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(faturamento_simples.keys(), faturamento_simples.values(), color='mediumseagreen')
ax.set_title('Faturamento Total (Somente Preço) por Loja')
ax.set_ylabel('R$')
ax.set_xlabel('Loja')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# Exibir o faturamento simples
print("Faturamento Simples (apenas preço) por Loja:")
for loja, valor in faturamento_simples.items():
    print(f"{loja}: R${valor:,.2f}")
# Out:
# Faturamento Simples (apenas preço) por Loja:
# loja_1: R$1,534,509.12
# loja_2: R$1,488,459.06
# loja_3: R$1,464,025.03
# loja_4: R$1,384,497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# prompt: import matplotlib.pyplot as plt
# # Contar produtos vendidos por categoria em cada loja
# categorias_por_loja = {nome: df['Categoria do Produto'].value_counts() for nome, df in lojas.items()}
# # Exibir gráficos de barras para cada loja
# fig, axs = plt.subplots(2, 2, figsize=(16, 10))
# fig.suptitle('Produtos Vendidos por Categoria em Cada Loja', fontsize=16)
# for ax, (nome_loja, categorias) in zip(axs.flatten(), categorias_por_loja.items()):
#     categorias.plot(kind='bar', ax=ax, color='coral')
#     ax.set_title(nome_loja)
#     ax.set_ylabel('Quantidade Vendida')
#     ax.set_xlabel('Categoria')
#     ax.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout(rect=[0, 0, 1, 0.95])
# plt.show()
# categorias_por_loja

# Contar produtos vendidos por categoria em cada loja
categorias_por_loja = {nome: df['Categoria do Produto'].value_counts() for nome, df in lojas.items()}

# Exibir gráficos de barras para cada loja
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('Produtos Vendidos por Categoria em Cada Loja', fontsize=16)

for ax, (nome_loja, categorias) in zip(axs.flatten(), categorias_por_loja.items()):
    categorias.plot(kind='bar', ax=ax, color='coral')
    ax.set_title(nome_loja)
    ax.set_ylabel('Quantidade Vendida')
    ax.set_xlabel('Categoria')
    ax.grid(axis='y', linestyle='--', alpha=0.7)
    ax.tick_params(axis='x', rotation=45)  # Rotacionar rótulos do eixo x

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

categorias_por_loja
# Out:
# {'loja_1': Categoria do Produto
#  moveis                   465
#  eletronicos              448
#  brinquedos               324
#  eletrodomesticos         312
#  esporte e lazer          284
#  instrumentos musicais    182
#  livros                   173
#  utilidades domesticas    171
#  Name: count, dtype: int64,
#  'loja_2': Categoria do Produto
#  moveis                   442
#  eletronicos              422
#  brinquedos               313
#  eletrodomesticos         305
#  esporte e lazer          275
#  instrumentos musicais    224
#  livros                   197
#  utilidades domesticas    181
#  Name: count, dtype: int64,
#  'loja_3': Categoria do Produto
#  moveis                   499
#  eletronicos              451
#  brinquedos               315
#  eletrodomesticos         278
#  esporte e lazer          277
#  livros                   185
#  instrumentos musicais    177
#  utilidades domesticas    177
#  Name: count, dtype: int64,
#  'loja_4': Categoria do Produto
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# prompt: # Calcular a média de avaliação das compras por loja
# avaliacao_media_por_loja = {nome: df['Avaliação da compra'].mean() for nome, df in lojas.items()}
# # Exibir gráfico
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.bar(avaliacao_media_por_loja.keys(), avaliacao_media_por_loja.values(), color='goldenrod')
# ax.set_title('Média de Avaliação dos Clientes por Loja')
# ax.set_ylabel('Nota Média (1 a 5)')
# ax.set_xlabel('Loja')
# ax.set_ylim(0, 5)
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# avaliacao_media_por_loja

# Calcular a média de avaliação das compras por loja
avaliacao_media_por_loja = {nome: df['Avaliação da compra'].mean() for nome, df in lojas.items()}

# Exibir gráfico
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(avaliacao_media_por_loja.keys(), avaliacao_media_por_loja.values(), color='goldenrod')
ax.set_title('Média de Avaliação dos Clientes por Loja')
ax.set_ylabel('Nota Média (1 a 5)')
ax.set_xlabel('Loja')
ax.set_ylim(0, 5)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Exibir a avaliação média por loja
avaliacao_media_por_loja
# Out:
# {'loja_1': np.float64(3.976685036032217),
#  'loja_2': np.float64(4.037303942348453),
#  'loja_3': np.float64(4.048325561678677),
#  'loja_4': np.float64(3.9957591178965224)}

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# prompt: # Contar os produtos mais e menos vendidos por loja
# mais_vendidos = {}
# menos_vendidos = {}
# for nome, df in lojas.items():
#     contagem_produtos = df['Produto'].value_counts()
#     mais_vendidos[nome] = contagem_produtos.head(3)
#     menos_vendidos[nome] = contagem_produtos.tail(3)
# # Visualizar os mais vendidos em gráficos
# fig, axs = plt.subplots(2, 2, figsize=(16, 10))
# fig.suptitle('Top 3 Produtos Mais Vendidos por Loja', fontsize=16)
# for ax, (nome_loja, produtos) in zip(axs.flatten(), mais_vendidos.items()):
#     produtos.plot(kind='barh', ax=ax, color='seagreen')
#     ax.set_title(nome_loja)
#     ax.set_xlabel('Quantidade Vendida')
#     ax.set_ylabel('Produto')
#     ax.invert_yaxis()
# plt.tight_layout(rect=[0, 0, 1, 0.95])
# plt.show()
# mais_vendidos, menos_vendidos

# Contar os produtos mais e menos vendidos por loja
mais_vendidos = {}
menos_vendidos = {}
for nome, df in lojas.items():
    contagem_produtos = df['Produto'].value_counts()
    mais_vendidos[nome] = contagem_produtos.head(3)
    menos_vendidos[nome] = contagem_produtos.tail(3)

# Visualizar os mais vendidos em gráficos
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('Top 3 Produtos Mais Vendidos por Loja', fontsize=16)
for ax, (nome_loja, produtos) in zip(axs.flatten(), mais_vendidos.items()):
    produtos.plot(kind='barh', ax=ax, color='seagreen')
    ax.set_title(nome_loja)
    ax.set_xlabel('Quantidade Vendida')
    ax.set_ylabel('Produto')
    ax.invert_yaxis()
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# Visualizar os menos vendidos em gráficos
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('Top 3 Produtos Menos Vendidos por Loja', fontsize=16)
for ax, (nome_loja, produtos) in zip(axs.flatten(), menos_vendidos.items()):
    produtos.plot(kind='barh', ax=ax, color='skyblue')
    ax.set_title(nome_loja)
    ax.set_xlabel('Quantidade Vendida')
    ax.set_ylabel('Produto')
    ax.invert_yaxis()
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

mais_vendidos, menos_vendidos
# Out:
# ({'loja_1': Produto
#   Micro-ondas      60
#   TV Led UHD 4K    60
#   Guarda roupas    60
#   Name: count, dtype: int64,
#   'loja_2': Produto
#   Iniciando em programação    65
#   Micro-ondas                 62
#   Bateria                     61
#   Name: count, dtype: int64,
#   'loja_3': Produto
#   Kit banquetas     57
#   Mesa de jantar    56
#   Cama king         56
#   Name: count, dtype: int64,
#   'loja_4': Produto
#   Cama box                   62
#   Faqueiro                   59
#   Dashboards com Power BI    56
#   Name: count, dtype: int64},
#  {'loja_1': Produto
#   Panela de pressão    35
#   Headset              33
#   Celular ABXY         33
#   Name: count, dtype: int64,
#   'loja_2': Produto
#   Mesa de jantar       34
#   Impressora           34
#   Jogo de tabuleiro    32
#   Name: count, dtype: int64,
#   'loja_3': Produto
#   Mochila             36
#   Micro-ondas         36
#   Blocos de montar    35
#   Name: count, dtype: int64,
#   'loja_4': Produto
# ...

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
# prompt: # Calcular o custo médio de frete por loja
# frete_medio_por_loja = {nome: df['Frete'].mean() for nome, df in lojas.items()}
# # Exibir gráfico
# fig, ax = plt.subplots(figsize=(10, 5))
# ax.bar(frete_medio_por_loja.keys(), frete_medio_por_loja.values(), color='steelblue')
# ax.set_title('Custo Médio de Frete por Loja')
# ax.set_ylabel('R$ (Média do Frete)')
# ax.set_xlabel('Loja')
# plt.grid(axis='y', linestyle='--', alpha=0.7)
# plt.tight_layout()
# plt.show()
# frete_medio_por_loja

# Calcular o custo médio de frete por loja
frete_medio_por_loja = {nome: df['Frete'].mean() for nome, df in lojas.items()}

# Exibir gráfico
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(frete_medio_por_loja.keys(), frete_medio_por_loja.values(), color='steelblue')
ax.set_title('Custo Médio de Frete por Loja')
ax.set_ylabel('R$ (Média do Frete)')
ax.set_xlabel('Loja')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Exibir o frete médio por loja
print("Frete Médio por Loja:")
for loja, valor in frete_medio_por_loja.items():
    print(f"{loja}: R${valor:,.2f}")
# Out:
# Frete Médio por Loja:
# loja_1: R$34.69
# loja_2: R$33.62
# loja_3: R$33.07
# loja_4: R$31.28

# %%
# prompt: import seaborn as sns
# # Preparando dados auxiliares
# df_resumo = pd.DataFrame({
#     "Loja": list(faturamento_simples.keys()),
#     "Faturamento": list(faturamento_simples.values()),
#     "Frete Médio": list(frete_medio_por_loja.values()),
#     "Avaliação Média": list(avaliacao_media_por_loja.values())
# })
# # Gráfico 1: Barras - Faturamento
# plt.figure(figsize=(8, 5))
# sns.barplot(data=df_resumo, x="Loja", y="Faturamento", palette="Blues_d")
# plt.title("Faturamento Total por Loja")
# plt.ylabel("R$ Total")
# plt.grid(axis="y", linestyle="--", alpha=0.7)
# plt.tight_layout()
# plt.show()
# # Gráfico 2: Dispersão - Avaliação x Frete
# plt.figure(figsize=(8, 5))
# sns.scatterplot(data=df_resumo, x="Frete Médio", y="Avaliação Média", hue="Loja", s=100)
# plt.title("Relação entre Frete Médio e Avaliação Média")
# plt.xlabel("Frete Médio (R$)")
# plt.ylabel("Avaliação Média")
# plt.grid(True)
# plt.tight_layout()
# plt.show()
# # Gráfico 3: Barras Horizontais - Produtos mais vendidos das lojas
# fig, axs = plt.subplots(2, 2, figsize=(16, 10))
# fig.suptitle("Top 3 Produtos Mais Vendidos por Loja", fontsize=16)
# for ax, (nome_loja, produtos) in zip(axs.flatten(), mais_vendidos.items()):
#     produtos.plot(kind='barh', ax=ax, color='darkorange')
#     ax.set_title(nome_loja)
#     ax.set_xlabel('Quantidade Vendida')
#     ax.set_ylabel('Produto')
#     ax.invert_yaxis()
# plt.tight_layout(rect=[0, 0, 1, 0.95])
# plt.show()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ... (your existing code for data loading and calculations) ...

# Preparando dados auxiliares
df_resumo = pd.DataFrame({
    "Loja": list(faturamento_simples.keys()),
    "Faturamento": list(faturamento_simples.values()),
    "Frete Médio": list(frete_medio_por_loja.values()),
    "Avaliação Média": list(avaliacao_media_por_loja.values())
})

# Gráfico 1: Barras - Faturamento
plt.figure(figsize=(8, 5))
sns.barplot(data=df_resumo, x="Loja", y="Faturamento", palette="Blues_d")
plt.title("Faturamento Total por Loja")
plt.ylabel("R$ Total")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.tight_layout()
plt.show()

# Gráfico 2: Dispersão - Avaliação x Frete
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df_resumo, x="Frete Médio", y="Avaliação Média", hue="Loja", s=100)
plt.title("Relação entre Frete Médio e Avaliação Média")
plt.xlabel("Frete Médio (R$)")
plt.ylabel("Avaliação Média")
plt.grid(True)
plt.tight_layout()
plt.show()

# Gráfico 3: Barras Horizontais - Produtos mais vendidos das lojas
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle("Top 3 Produtos Mais Vendidos por Loja", fontsize=16)
for ax, (nome_loja, produtos) in zip(axs.flatten(), mais_vendidos.items()):
    produtos.plot(kind='barh', ax=ax, color='darkorange')
    ax.set_title(nome_loja)
    ax.set_xlabel('Quantidade Vendida')
    ax.set_ylabel('Produto')
    ax.invert_yaxis()
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# <ipython-input-21-dc9ed6f0194d>:54: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_resumo, x="Loja", y="Faturamento", palette="Blues_d")

# %% [markdown]
# # 📋 Relatório Final – Análise de Desempenho das Lojas da Alura Store
#
# ## 🎯 Introdução
#
# O objetivo desta análise é apoiar o Senhor João na tomada de decisão sobre **qual loja da rede Alura Store deve ser vendida** para dar início a um novo empreendimento. Para isso, realizamos um estudo comparativo entre as quatro lojas, considerando aspectos como **faturamento, perfil de produtos vendidos, satisfação dos clientes e custos operacionais**, com base nos dados disponíveis e visualizações geradas.
#
# ---
#
# ## 📊 Desenvolvimento
#
# ### 1. Faturamento Total
#
# Analisando a soma dos valores da coluna “Preço”:
#
# - **Loja 1** → R$ 1.534.509,12 (maior faturamento)
# - **Loja 4** → R$ 1.384.497,58 (menor faturamento)
#
# 📌 A **Loja 4 apresenta o menor desempenho financeiro**, mesmo com volume de vendas próximo às demais.
#
# ---
#
# ### 2. Categorias de Produtos Vendidos
#
# As três categorias mais vendidas em todas as lojas foram:
#
# - **Móveis**
# - **Eletrônicos**
# - **Brinquedos**
#
# 📌 A **Loja 4** segue esse padrão, mas **não se destaca em nenhuma categoria** como líder absoluta de vendas.
#
# ---
#
# ### 3. Avaliações dos Clientes
#
# Média das avaliações de 1 a 5:
#
# - **Loja 3** → 4,05 ⭐ (melhor desempenho)
# - **Loja 4** → 4,00 ⭐
# - **Loja 1** → 3,98 ⭐ (pior média)
#
# 📌 A **Loja 4 tem avaliação razoável**, porém não superior o suficiente para compensar o baixo faturamento.
#
# ---
#
# ### 4. Produtos Mais e Menos Vendidos
#
# **Mais vendidos da Loja 4**:
# - Cama box (62)
# - Faqueiro (59)
# - Dashboards com Power BI (56)
#
# **Menos vendidos da Loja 4**:
# - Guitarra (33)
# - Guarda-roupas (34)
# - Violão (37)
#
# 📌 Apesar de alguns bons desempenhos, **a Loja 4 concentra diversos produtos com pouca saída**, o que reduz sua competitividade.
#
# ---
#
# ### 5. Custo Médio de Frete
#
# - **Loja 4** → R$ 31,28 (menor custo de frete entre as lojas)
# - **Loja 1** → R$ 34,69 (maior custo)
#
# 📌 Mesmo com o **frete mais barato**, a Loja 4 **não converte esse diferencial em maior faturamento**.
#
# ---
#
# ## ✅ Conclusão e Recomendação
#
# Com base em todas as análises e gráficos, a **Loja 4 é a indicada para ser vendida**. Essa decisão é sustentada pelos seguintes fatores:
#
# - **Menor faturamento total**
# - **Portfólio de produtos com menor apelo comercial**
# - **Menor diversidade entre os mais vendidos**
# - **Desempenho mediano nas avaliações**
# - **Frete competitivo, mas com impacto irrelevante nas vendas**
#
# 💡 Dessa forma, o Senhor João pode **manter as lojas com maior retorno financeiro e melhor reputação**, maximizando os recursos disponíveis para investir em seu novo empreendimento com segurança e estratégia.
#
# ---

# %%
# prompt: # Criar um gráfico de dispersão geográfico com base nas coordenadas de latitude e longitude
# fig, axs = plt.subplots(2, 2, figsize=(16, 10))
# fig.suptitle('Distribuição Geográfica das Vendas por Loja (Latitude vs Longitude)', fontsize=16)
# for ax, (nome_loja, df) in zip(axs.flatten(), lojas.items()):
#     sc = ax.scatter(df['lon'], df['lat'], alpha=0.4, s=10, label=nome_loja, c=df['Avaliação da compra'], cmap='viridis')
#     ax.set_title(nome_loja)
#     ax.set_xlabel('Longitude')
#     ax.set_ylabel('Latitude')
#     ax.grid(True)
#     ax.legend()
# # Adicionar uma barra de cores para as avaliações
# cbar = fig.colorbar(sc, ax=axs.ravel().tolist(), orientation='vertical')
# cbar.set_label('Avaliação da Compra')
# plt.tight_layout(rect=[0, 0, 1, 0.95])
# plt.show()

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# ... (your existing code for data loading and calculations) ...

# Criar um gráfico de dispersão geográfico com base nas coordenadas de latitude e longitude
fig, axs = plt.subplots(2, 2, figsize=(16, 10))
fig.suptitle('Distribuição Geográfica das Vendas por Loja (Latitude vs Longitude)', fontsize=16)

for ax, (nome_loja, df) in zip(axs.flatten(), lojas.items()):
    # Verificar se as colunas 'lon' e 'lat' existem no DataFrame
    if 'lon' in df.columns and 'lat' in df.columns:
        sc = ax.scatter(df['lon'], df['lat'], alpha=0.4, s=10, label=nome_loja, c=df['Avaliação da compra'], cmap='viridis')
        ax.set_title(nome_loja)
        ax.set_xlabel('Longitude')
        ax.set_ylabel('Latitude')
        ax.grid(True)
        ax.legend()
    else:
        ax.text(0.5, 0.5, "Colunas 'lon' ou 'lat' ausentes", ha='center', va='center', fontsize=12, color='red')

# Adicionar uma barra de cores para as avaliações, se o scatter plot foi criado
if 'sc' in locals():
    cbar = fig.colorbar(sc, ax=axs.ravel().tolist(), orientation='vertical')
    cbar.set_label('Avaliação da Compra')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# <ipython-input-22-ba79dfd43d56>:44: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
